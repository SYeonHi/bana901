# %% [markdown]
# <a href="https://colab.research.google.com/github/SYeonHi/bana901/blob/main/AI%EB%8C%80%ED%9A%8C_07022313.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.25.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.3.0+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.3.post0-py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 59.1 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->torchmetrics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->torchmetrics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics
# Successfully installed lightning-utilities-0.11.3.post0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 torchmetrics-1.4.0.post0

# %%
import librosa

from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import random

from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

import torch
import torchmetrics
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !gdown https://drive.google.com/uc?id=1hi1dibkHyFbaxAteLlZJw6r3g9ddd4Lf
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1hi1dibkHyFbaxAteLlZJw6r3g9ddd4Lf
# From (redirected): https://drive.google.com/uc?id=1hi1dibkHyFbaxAteLlZJw6r3g9ddd4Lf&confirm=t&uuid=6c13d202-f4a7-417d-8917-21f8e309f380
# To: /content/open.zip
# 100% 3.31G/3.31G [00:35<00:00, 92.8MB/s]

# %%
# !unzip /content/open.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: train/YGLREVCI.ogg
#   inflating: train/YGLXWFHV.ogg
#   inflating: train/YGMDZXNH.ogg
#   inflating: train/YGNBHIJR.ogg
#   inflating: train/YGNYUVFD.ogg
#   inflating: train/YGOBSHQC.ogg
#   inflating: train/YGOHGPYC.ogg
#   inflating: train/YGOJCZPI.ogg
#   inflating: train/YGOPJRGB.ogg
#   inflating: train/YGOUDQAW.ogg
#   inflating: train/YGOVHKGM.ogg
#   inflating: train/YGPAVGYX.ogg
#   inflating: train/YGPBFKRL.ogg
#   inflating: train/YGPKBYES.ogg
#   inflating: train/YGPLMREG.ogg
#   inflating: train/YGPPRAEG.ogg
#   inflating: train/YGQYKVKC.ogg
#   inflating: train/YGSHBSPQ.ogg
#   inflating: train/YGSOQIHH.ogg
#   inflating: train/YGSVKSRM.ogg
#   inflating: train/YGTHJFJE.ogg
#   inflating: train/YGTVQNQS.ogg
#   inflating: train/YGTZZFQG.ogg
#   inflating: train/YGUHCKOU.ogg
#   inflating: train/YGUXKMIZ.ogg
#   inflating: train/YGVFWCTP.ogg
#   inflating: train/YGVHVEZO.ogg
#   inflating: train/YGVMNLVT.ogg
#   inflating: train/YGVOLHDK.ogg
#   inflating: train/YGWACYNM.ogg
#   inflating: train/YGWFSDRD.ogg
#   inflating: train/YGWTPKXW.ogg
#   inflating: train/YGWVCIGM.ogg
#   inflating: train/YGWWKSWB.ogg
#   inflating: train/YGXHENNG.ogg
#   inflating: train/YGXOOQIY.ogg
#   inflating: train/YGXTZHVO.ogg
#   inflating: train/YGYDAFLQ.ogg
#   inflating: train/YGYWYQWN.ogg
#   inflating: train/YGYYBAKV.ogg
#   inflating: train/YGYZVQPD.ogg
#   inflating: train/YGZBYBMP.ogg
#   inflating: train/YGZELJKU.ogg
#   inflating: train/YGZGJEAW.ogg
#   inflating: train/YGZQITAC.ogg
#   inflating: train/YGZZHOXH.ogg
#   inflating: train/YHANNYJS.ogg
#   inflating: train/YHAPCBVP.ogg
#   inflating: train/YHAQBEIU.ogg
#   inflating: train/YHAUGJIT.ogg
#   inflating: train/YHAVYCCL.ogg
#   inflating: train/YHAYLZQD.ogg
#   inflating: train/YHBGCYFW.ogg
#   inflating: train/YHBKHXKV.ogg
#   inflating: train/YHBLQJAQ.ogg
#   inflating: train/YHBNAJRR.ogg
#   inflating: train/YHCINNHJ.ogg
#   inflating: train/YHCNKXIN.ogg
#   inflating: train/YHCUSQYV.ogg
#   inflating: train/YHCYEJSP.ogg
#   inflating: train/YHDABMKO.ogg
#   inflating: train/YHDVBYOQ.ogg
#   inflating: train/YHEBVWTQ.ogg
#   inflating: train/YHEZWUMQ.ogg
#   inflating: train/YHFGBJMI.ogg
#   inflating: train/YHFPYDMB.ogg
#   inflating: train/YHFSXEFQ.ogg
#   inflating: train/YHFTYKHY.ogg
#   inflating: train/YHGCOPGR.ogg
#   inflating: train/YHGRJFOT.ogg
#   inflating: train/YHHDJQVM.ogg
#   inflating: train/YHHQCYPU.ogg
#   inflating: train/YHHRLMKE.ogg
#   inflating: train/YHHUQXWN.ogg
#   inflating: train/YHIKCGBC.ogg
#   inflating: train/YHIUZDGI.ogg
#   inflating: train/YHJLVWIT.ogg
#   inflating: train/YHJNDGGY.ogg
#   inflating: train/YHJPCPOR.ogg
#   inflating: train/YHJPENRG.ogg
#   inflating: train/YHKIIPGL.ogg
#   inflating: train/YHKQJCGT.ogg
#   inflating: train/YHLCZRZY.ogg
#   inflating: train/YHLPOLGX.ogg
#   inflating: train/YHLTUDEI.ogg
#   inflating: train/YHMBKPXC.ogg
#   inflating: train/YHMGXBGC.ogg
#   inflating: train/YHMNCWIN.ogg
#   inflating: train/YHMTAVKZ.ogg
#   inflating: train/YHMTEQQP.ogg
#   inflating: train/YHNQYZOJ.ogg
#   inflating: train/YHOHOOVQ.ogg
#   inflating: train/YHOMMWQJ.ogg
#   inflating: train/YHOQEOEP.ogg
#   inflating: train/YHORXAXR.ogg
#   inflating: train/YHOUHCDD.ogg
#   inflating: train/YHOZSHVG.ogg
#   inflating: train/YHPJRGGH.ogg
#   inflating: train/YHPTEQPS.ogg
#   inflating: train/YHQBQQXW.ogg
#   inflating: train/YHRQCOMZ.ogg
#   inflating: train/YHRZDZHC.ogg
#   inflating: train/YHTONUOV.ogg
#   inflating: train/YHUNDJGX.ogg
#   inflating: train/YHUOEZFE.ogg
#   inflating: train/YHURJSWZ.ogg
#   inflating: train/YHUZAPJZ.ogg
#   inflating: train/YHVIACOQ.ogg
#   inflating: train/YHVNSIUH.ogg
#   inflating: train/YHWOYJZX.ogg
#   inflating: train/YHXDVXJX.ogg
#   inflating: train/YHXOMQYG.ogg
#   inflating: train/YHYBXNDK.ogg
#   inflating: train/YHYHDZXM.ogg
#   inflating: train/YHYLZKOU.ogg
#   inflating: train/YHYRGYCC.ogg
#   inflating: train/YHZHTWRQ.ogg
#   inflating: train/YHZVWSTP.ogg
#   inflating: train/YIAAFFHB.ogg
#   inflating: train/YIBIXJBW.ogg
#   inflating: train/YIBJLTCO.ogg
#   inflating: train/YIBKISMX.ogg
#   inflating: train/YIBOORXC.ogg
#   inflating: train/YICHIPWC.ogg
#   inflating: train/YICXISZH.ogg
#   inflating: train/YIDYSUPD.ogg
#   inflating: train/YIEBFHRM.ogg
#   inflating: train/YIECMXCP.ogg
#   inflating: train/YIEHQYBU.ogg
#   inflating: train/YIEJIILP.ogg
#   inflating: train/YIEKVALX.ogg
#   inflating: train/YIERTYSO.ogg
#   inflating: train/YIEZVFCE.ogg
#   inflating: train/YIFASJZM.ogg
#   inflating: train/YIFBWKAF.ogg
#   inflating: train/YIFMIOIM.ogg
#   inflating: train/YIFPPBRB.ogg
#   inflating: train/YIFVWNBZ.ogg
#   inflating: train/YIGDNTQM.ogg
#   inflating: train/YIGHOIBN.ogg
#   inflating: train/YIGYIPKX.ogg
#   inflating: train/YIHCKBXV.ogg
#   inflating: train/YIIDDXAX.ogg
#   inflating: train/YIIHSERA.ogg
#   inflating: train/YIIQJPGL.ogg
#   inflating: train/YIITKAUP.ogg
#   inflating: train/YIIZELIU.ogg
#   inflating: train/YIJFOFIJ.ogg
#   inflating: train/YIJNDZAS.ogg
#   inflating: train/YIJPIRVQ.ogg
#   inflating: train/YIJUCBFY.ogg
#   inflating: train/YIKCDUUI.ogg
#   inflating: train/YIKEBMKC.ogg
#   inflating: train/YIKOQGZU.ogg
#   inflating: train/YILBDNCB.ogg
#   inflating: train/YILRCJJT.ogg
#   inflating: train/YILVWHJB.ogg
#   inflating: train/YIMSEGUP.ogg
#   inflating: train/YIMZRFVZ.ogg
#   inflating: train/YINFKEWL.ogg
#   inflating: train/YINKVIBR.ogg
#   inflating: train/YINMEQNL.ogg
#   inflating: train/YIOEUMZA.ogg
#   inflating: train/YIOIXNIQ.ogg
#   inflating: train/YIPLLZEV.ogg
#   inflating: train/YIPQRRNA.ogg
#   inflating: train/YIPRTZGH.ogg
#   inflating: train/YIPTRCHU.ogg
#   inflating: train/YIPUXRYF.ogg
#   inflating: train/YIQICPFA.ogg
#   inflating: train/YIQJGKDT.ogg
#   inflating: train/YIQNWBJO.ogg
#   inflating: train/YIQQGVRB.ogg
#   inflating: train/YIRDSVHO.ogg
#   inflating: train/YIRPFTXO.ogg
#   inflating: train/YIRSZRCZ.ogg
#   inflating: train/YISHAYMQ.ogg
#   inflating: train/YISHQBTY.ogg
#   inflating: train/YISZWHVL.ogg
#   inflating: train/YITAHRUJ.ogg
#   inflating: train/YITCYZIM.ogg
#   inflating: train/YITNWMQP.ogg
#   inflating: train/YITQKMEC.ogg
#   inflating: train/YITRYDCJ.ogg
#   inflating: train/YIUOSBPV.ogg
#   inflating: train/YIVHFWOX.ogg
#   inflating: train/YIVIOSOL.ogg
#   inflating: train/YIVREJYN.ogg
#   inflating: train/YIWCVEUT.ogg
#   inflating: train/YIWFPEPV.ogg
#   inflating: train/YIWJHABU.ogg
#   inflating: train/YIXWCHNR.ogg
#   inflating: train/YIYYXEHE.ogg
#   inflating: train/YIZCUHXV.ogg
#   inflating: train/YIZDWSNA.ogg
#   inflating: train/YIZGBWKS.ogg
#   inflating: train/YIZUINXF.ogg
#   inflating: train/YJANFVUQ.ogg
#   inflating: train/YJARNCBN.ogg
#   inflating: train/YJAYRMRP.ogg
#   inflating: train/YJCEHMVV.ogg
#   inflating: train/YJCFGXHY.ogg
#   inflating: train/YJCQSGDI.ogg
#   inflating: train/YJCVRVJG.ogg
#   inflating: train/YJCYHLFN.ogg
#   inflating: train/YJCYOKFM.ogg
#   inflating: train/YJDEVZCY.ogg
#   inflating: train/YJDHOJZG.ogg
#   inflating: train/YJDLUVIK.ogg
#   inflating: train/YJEOJHAS.ogg
#   inflating: train/YJESXFXN.ogg
#   inflating: train/YJFBPRZL.ogg
#   inflating: train/YJFSIBCR.ogg
#   inflating: train/YJGPTEXU.ogg
#   inflating: train/YJGTERZO.ogg
#   inflating: train/YJHBMFLG.ogg
#   inflating: train/YJHNLUQI.ogg
#   inflating: train/YJHTUAAA.ogg
#   inflating: train/YJHWCPBJ.ogg
#   inflating: train/YJIAYNOZ.ogg
#   inflating: train/YJIFLOUK.ogg
#   inflating: train/YJJICMUL.ogg
#   inflating: train/YJJPPPSE.ogg
#   inflating: train/YJJXUGVE.ogg
#   inflating: train/YJKASVEI.ogg
#   inflating: train/YJKGZVAQ.ogg
#   inflating: train/YJKKAYLL.ogg
#   inflating: train/YJKWFKOO.ogg
#   inflating: train/YJLMZTOE.ogg
#   inflating: train/YJMRMYSE.ogg
#   inflating: train/YJNKMGQT.ogg
#   inflating: train/YJOAXLXH.ogg
#   inflating: train/YJOCSRSI.ogg
#   inflating: train/YJOIYHLG.ogg
#   inflating: train/YJOMRFLD.ogg
#   inflating: train/YJOOFOXJ.ogg
#   inflating: train/YJOUSUHR.ogg
#   inflating: train/YJOVHDDM.ogg
#   inflating: train/YJOWDPFG.ogg
#   inflating: train/YJOYKHNL.ogg
#   inflating: train/YJPDWOFS.ogg
#   inflating: train/YJPMEFTO.ogg
#   inflating: train/YJPOBARO.ogg
#   inflating: train/YJQCIYBU.ogg
#   inflating: train/YJQHNJWP.ogg
#   inflating: train/YJQNBHML.ogg
#   inflating: train/YJQUVOPA.ogg
#   inflating: train/YJQWQVSR.ogg
#   inflating: train/YJRGYULH.ogg
#   inflating: train/YJRVCHYE.ogg
#   inflating: train/YJRXRMNB.ogg
#   inflating: train/YJSDFXXC.ogg
#   inflating: train/YJSILVNB.ogg
#   inflating: train/YJSNWFYX.ogg
#   inflating: train/YJSXPGDG.ogg
#   inflating: train/YJSZCNSQ.ogg
#   inflating: train/YJTHMZZX.ogg
#   inflating: train/YJTUEGFF.ogg
#   inflating: train/YJUOFLGF.ogg
#   inflating: train/YJUQIMPU.ogg
#   inflating: train/YJWHOIXC.ogg
#   inflating: train/YJWMTTYU.ogg
#   inflating: train/YJWRWBIS.ogg
#   inflating: train/YJWUIHSM.ogg
#   inflating: train/YJXBVJKR.ogg
#   inflating: train/YJXFHYBS.ogg
#   inflating: train/YJXNKCFH.ogg
#   inflating: train/YJXTZAGH.ogg
#   inflating: train/YJXVXKVR.ogg
#   inflating: train/YJYGSEDT.ogg
#   inflating: train/YJYRRCCL.ogg
#   inflating: train/YJYUJFKA.ogg
#   inflating: train/YJYYICQT.ogg
#   inflating: train/YJZKWYBA.ogg
#   inflating: train/YJZSJHLA.ogg
#   inflating: train/YJZVUUQO.ogg
#   inflating: train/YKAISOII.ogg
#   inflating: train/YKBANTQH.ogg
#   inflating: train/YKBIVTKK.ogg
#   inflating: train/YKBRPVZA.ogg
#   inflating: train/YKCWLOXQ.ogg
#   inflating: train/YKDYUGYH.ogg
#   inflating: train/YKDZWPNZ.ogg
#   inflating: train/YKECYUWR.ogg
#   inflating: train/YKEIXXTW.ogg
#   inflating: train/YKELIOMD.ogg
#   inflating: train/YKENFYEH.ogg
#   inflating: train/YKFTUFEF.ogg
#   inflating: train/YKGRVYOP.ogg
#   inflating: train/YKGTQJZF.ogg
#   inflating: train/YKGVLZHE.ogg
#   inflating: train/YKHARJSS.ogg
#   inflating: train/YKHEUQMW.ogg
#   inflating: train/YKIGSTFL.ogg
#   inflating: train/YKIKHAIB.ogg
#   inflating: train/YKIPIZOS.ogg
#   inflating: train/YKIUEJCZ.ogg
#   inflating: train/YKIYZOHQ.ogg
#   inflating: train/YKJAHFYR.ogg
#   inflating: train/YKJKFZGS.ogg
#   inflating: train/YKKDLAPU.ogg
#   inflating: train/YKKFQVIF.ogg
#   inflating: train/YKKKEAUC.ogg
#   inflating: train/YKLARKSY.ogg
#   inflating: train/YKMJEQVN.ogg
#   inflating: train/YKMJROQY.ogg
#   inflating: train/YKMNOAKA.ogg
#   inflating: train/YKMOOPRJ.ogg
#   inflating: train/YKMXNOZM.ogg
#   inflating: train/YKNGJFXR.ogg
#   inflating: train/YKNPVGRY.ogg
#   inflating: train/YKNSSTDX.ogg
#   inflating: train/YKNTXJAG.ogg
#   inflating: train/YKPGICYJ.ogg
#   inflating: train/YKPLLCVO.ogg
#   inflating: train/YKPLPWRL.ogg
#   inflating: train/YKPZLYCO.ogg
#   inflating: train/YKQJPBUY.ogg
#   inflating: train/YKRUGHVG.ogg
#   inflating: train/YKTDBUNQ.ogg
#   inflating: train/YKTFXHHJ.ogg
#   inflating: train/YKTSYIOS.ogg
#   inflating: train/YKUBCHXD.ogg
#   inflating: train/YKUPXEDP.ogg
#   inflating: train/YKUWQKCD.ogg
#   inflating: train/YKVEHBXV.ogg
#   inflating: train/YKVGXNHL.ogg
#   inflating: train/YKVOVXYH.ogg
#   inflating: train/YKVRSOIP.ogg
#   inflating: train/YKVVPTVC.ogg
#   inflating: train/YKVVXDYZ.ogg
#   inflating: train/YKWHUKUX.ogg
#   inflating: train/YKWKJDRC.ogg
#   inflating: train/YKWMYLDT.ogg
#   inflating: train/YKWUSZVD.ogg
#   inflating: train/YKXDGDGD.ogg
#   inflating: train/YKXDNXZE.ogg
#   inflating: train/YKXWBXCT.ogg
#   inflating: train/YKXZZSVS.ogg
#   inflating: train/YKYJNIFP.ogg
#   inflating: train/YKYNYIYM.ogg
#   inflating: train/YKYSUVDM.ogg
#   inflating: train/YKZONYTR.ogg
#   inflating: train/YKZRLOJG.ogg
#   inflating: train/YKZTHRRR.ogg
#   inflating: train/YLABHHIO.ogg
#   inflating: train/YLADRNGE.ogg
#   inflating: train/YLATKYTL.ogg
#   inflating: train/YLAZBPPO.ogg
#   inflating: train/YLBJRUNG.ogg
#   inflating: train/YLBNWXNT.ogg
#   inflating: train/YLBTZDMI.ogg
#   inflating: train/YLCJVOVI.ogg
#   inflating: train/YLCOLLHT.ogg
#   inflating: train/YLDCYMLS.ogg
#   inflating: train/YLDDPAPF.ogg
#   inflating: train/YLDDUCXW.ogg
#   inflating: train/YLDHPVST.ogg
#   inflating: train/YLDOQXLO.ogg
#   inflating: train/YLDREKHQ.ogg
#   inflating: train/YLEDSNUD.ogg
#   inflating: train/YLELGGVJ.ogg
#   inflating: train/YLERCJJY.ogg
#   inflating: train/YLETDDQQ.ogg
#   inflating: train/YLETDYZK.ogg
#   inflating: train/YLEYJVOO.ogg
#   inflating: train/YLFGZJDD.ogg
#   inflating: train/YLFNMGIE.ogg
#   inflating: train/YLFYUEKE.ogg
#   inflating: train/YLGKBZOO.ogg
#   inflating: train/YLGVSRCA.ogg
#   inflating: train/YLHATGFX.ogg
#   inflating: train/YLHLJDDJ.ogg
#   inflating: train/YLHNJACG.ogg
#   inflating: train/YLHNOFKT.ogg
#   inflating: train/YLIBFKDM.ogg
#   inflating: train/YLIUUNCY.ogg
#   inflating: train/YLJTLHFX.ogg
#   inflating: train/YLJVDNPK.ogg
#   inflating: train/YLJYXHCG.ogg
#   inflating: train/YLKAWIMH.ogg
#   inflating: train/YLKIZIFJ.ogg
#   inflating: train/YLKUTIVC.ogg
#   inflating: train/YLKWUWDH.ogg
#   inflating: train/YLLCTJIU.ogg
#   inflating: train/YLLVSQAW.ogg
#   inflating: train/YLMETWVT.ogg
#   inflating: train/YLMIQTTO.ogg
#   inflating: train/YLNQRWFN.ogg
#   inflating: train/YLOMOIUZ.ogg
#   inflating: train/YLONXOUF.ogg
#   inflating: train/YLOQGYNZ.ogg
#   inflating: train/YLOUQTMQ.ogg
#   inflating: train/YLPHLQXH.ogg
#   inflating: train/YLPNBVBO.ogg
#   inflating: train/YLQYFFKP.ogg
#   inflating: train/YLQYUWJD.ogg
#   inflating: train/YLRESHYG.ogg
#   inflating: train/YLRHWSGD.ogg
#   inflating: train/YLSEWBGS.ogg
#   inflating: train/YLSZNQNE.ogg
#   inflating: train/YLSZTCPX.ogg
#   inflating: train/YLSZWNTD.ogg
#   inflating: train/YLTBMZYR.ogg
#   inflating: train/YLTJHNVV.ogg
#   inflating: train/YLTPCXVD.ogg
#   inflating: train/YLUGKTAC.ogg
#   inflating: train/YLUJCWET.ogg
#   inflating: train/YLUMWHWB.ogg
#   inflating: train/YLVBGNNH.ogg
#   inflating: train/YLVBLDQE.ogg
#   inflating: train/YLVDZSHP.ogg
#   inflating: train/YLVEWCYT.ogg
#   inflating: train/YLVHIBYL.ogg
#   inflating: train/YLVRYNZN.ogg
#   inflating: train/YLVUNBMH.ogg
#   inflating: train/YLVUVJQO.ogg
#   inflating: train/YLVWHNZW.ogg
#   inflating: train/YLVXYLUQ.ogg
#   inflating: train/YLWAYPLJ.ogg
#   inflating: train/YLWJQFNO.ogg
#   inflating: train/YLWLJFEC.ogg
#   inflating: train/YLWOFLCW.ogg
#   inflating: train/YLWTSZYY.ogg
#   inflating: train/YLXHNTMU.ogg
#   inflating: train/YLYCITCK.ogg
#   inflating: train/YLYMFFXP.ogg
#   inflating: train/YLYNQPEU.ogg
#   inflating: train/YLYNZGFP.ogg
#   inflating: train/YLZEMPXV.ogg
#   inflating: train/YLZIJQYL.ogg
#   inflating: train/YLZIULQX.ogg
#   inflating: train/YLZSHBXX.ogg
#   inflating: train/YLZTUCKY.ogg
#   inflating: train/YMAOTQSZ.ogg
#   inflating: train/YMAPQYBV.ogg
#   inflating: train/YMARZWEX.ogg
#   inflating: train/YMBFFNZA.ogg
#   inflating: train/YMBIXZSZ.ogg
#   inflating: train/YMBVDTGZ.ogg
#   inflating: train/YMCEHVBT.ogg
#   inflating: train/YMCEOZIE.ogg
#   inflating: train/YMCXOIAQ.ogg
#   inflating: train/YMCYZKEI.ogg
#   inflating: train/YMDHFFOK.ogg
#   inflating: train/YMDIKZBW.ogg
#   inflating: train/YMDJBELZ.ogg
#   inflating: train/YMDODMEQ.ogg
#   inflating: train/YMDRFAMR.ogg
#   inflating: train/YMDUHMPI.ogg
#   inflating: train/YMECOSDM.ogg
#   inflating: train/YMEQPXOP.ogg
#   inflating: train/YMGAOJTW.ogg
#   inflating: train/YMGDURVE.ogg
#   inflating: train/YMGKPMZM.ogg
#   inflating: train/YMGMPITU.ogg
#   inflating: train/YMGSSTIG.ogg
#   inflating: train/YMGVGMCW.ogg
#   inflating: train/YMHGSORD.ogg
#   inflating: train/YMHMAYST.ogg
#   inflating: train/YMILBHQM.ogg
#   inflating: train/YMINVFCI.ogg
#   inflating: train/YMITCQZP.ogg
#   inflating: train/YMJSHFJU.ogg
#   inflating: train/YMJVZXHO.ogg
#   inflating: train/YMKBCNCP.ogg
#   inflating: train/YMKPGNXA.ogg
#   inflating: train/YMKVQFRF.ogg
#   inflating: train/YMLRQPLY.ogg
#   inflating: train/YMLSMXMS.ogg
#   inflating: train/YMMCXIDI.ogg
#   inflating: train/YMMHLJAL.ogg
#   inflating: train/YMMHUTBS.ogg
#   inflating: train/YMMNGNPU.ogg
#   inflating: train/YMMXQSQQ.ogg
#   inflating: train/YMNHPUWW.ogg
#   inflating: train/YMNLTYHV.ogg
#   inflating: train/YMNORJQG.ogg
#   inflating: train/YMOCMGTF.ogg
#   inflating: train/YMOEEOTO.ogg
#   inflating: train/YMOGAEEW.ogg
#   inflating: train/YMOPNUXI.ogg
#   inflating: train/YMOUZRUV.ogg
#   inflating: train/YMPAUYPB.ogg
#   inflating: train/YMPHGXQI.ogg
#   inflating: train/YMPIRUDX.ogg
#   inflating: train/YMPLMGLN.ogg
#   inflating: train/YMPPEQIR.ogg
#   inflating: train/YMQAAYVJ.ogg
#   inflating: train/YMQAFWKG.ogg
#   inflating: train/YMQIYGQA.ogg
#   inflating: train/YMQTQNEK.ogg
#   inflating: train/YMRGJVZI.ogg
#   inflating: train/YMRTKOTG.ogg
#   inflating: train/YMRWWPJQ.ogg
#   inflating: train/YMSIPGGN.ogg
#   inflating: train/YMTBJRTT.ogg
#   inflating: train/YMTGBQBT.ogg
#   inflating: train/YMUDMLPT.ogg
#   inflating: train/YMUFEZZQ.ogg
#   inflating: train/YMVANQNE.ogg
#   inflating: train/YMVCKRWD.ogg
#   inflating: train/YMVHRXGT.ogg
#   inflating: train/YMVIBEYG.ogg
#   inflating: train/YMWFLMLF.ogg
#   inflating: train/YMXFCSIU.ogg
#   inflating: train/YMXZQZCM.ogg
#   inflating: train/YMYMSJQI.ogg
#   inflating: train/YMYNAZBF.ogg
#   inflating: train/YMYTAFRY.ogg
#   inflating: train/YMZPJZIN.ogg
#   inflating: train/YMZQZUBI.ogg
#   inflating: train/YNAIDSGH.ogg
#   inflating: train/YNAOXLFW.ogg
#   inflating: train/YNASCPBV.ogg
#   inflating: train/YNBDZHXX.ogg
#   inflating: train/YNBPEBNK.ogg
#   inflating: train/YNBUBIGZ.ogg
#   inflating: train/YNCEEUGA.ogg
#   inflating: train/YNCVJZAQ.ogg
#   inflating: train/YNDBFABL.ogg
#   inflating: train/YNDLWESJ.ogg
#   inflating: train/YNDPBGAN.ogg
#   inflating: train/YNDQHTVQ.ogg
#   inflating: train/YNDTUUAJ.ogg
#   inflating: train/YNEIXMJT.ogg
#   inflating: train/YNEJSLRC.ogg
#   inflating: train/YNEVIJQC.ogg
#   inflating: train/YNEZDRMI.ogg
#   inflating: train/YNFAIKCB.ogg
#   inflating: train/YNFHZCEQ.ogg
#   inflating: train/YNFWNQZS.ogg
#   inflating: train/YNFZOVQF.ogg
#   inflating: train/YNGBBAVF.ogg
#   inflating: train/YNGGMWYQ.ogg
#   inflating: train/YNGUEVXI.ogg
#   inflating: train/YNHETRMW.ogg
#   inflating: train/YNHWPNAF.ogg
#   inflating: train/YNIDCOPO.ogg
#   inflating: train/YNIFBJEF.ogg
#   inflating: train/YNIMQBHH.ogg
#   inflating: train/YNIVVTUV.ogg
#   inflating: train/YNIYPEOG.ogg
#   inflating: train/YNJBRAWV.ogg
#   inflating: train/YNJEKZVR.ogg
#   inflating: train/YNJGVHDX.ogg
#   inflating: train/YNJHJTPX.ogg
#   inflating: train/YNJXHVST.ogg
#   inflating: train/YNJZZITL.ogg
#   inflating: train/YNKEBTZZ.ogg
#   inflating: train/YNKROYQG.ogg
#   inflating: train/YNLCXRLQ.ogg
#   inflating: train/YNLNLPNW.ogg
#   inflating: train/YNLQVPMV.ogg
#   inflating: train/YNLTNKKW.ogg
#   inflating: train/YNMGPQSA.ogg
#   inflating: train/YNNEWZRM.ogg
#   inflating: train/YNNIKRND.ogg
#   inflating: train/YNNQONEX.ogg
#   inflating: train/YNOJKBDX.ogg
#   inflating: train/YNORIZEO.ogg
#   inflating: train/YNOTATFF.ogg
#   inflating: train/YNPFMFPQ.ogg
#   inflating: train/YNPHMHKL.ogg
#   inflating: train/YNPLNMPK.ogg
#   inflating: train/YNPVEFCN.ogg
#   inflating: train/YNQRUMHH.ogg
#   inflating: train/YNQWRNWG.ogg
#   inflating: train/YNRBNMFM.ogg
#   inflating: train/YNRCPTDW.ogg
#   inflating: train/YNRLPVYC.ogg
#   inflating: train/YNRMVZRM.ogg
#   inflating: train/YNRMYLFN.ogg
#   inflating: train/YNTGTGIO.ogg
#   inflating: train/YNTLGNOF.ogg
#   inflating: train/YNTLIWHN.ogg
#   inflating: train/YNUCKKGH.ogg
#   inflating: train/YNUIGIJO.ogg
#   inflating: train/YNUNUIPX.ogg
#   inflating: train/YNVGMHIO.ogg
#   inflating: train/YNVIHARM.ogg
#   inflating: train/YNVPNVID.ogg
#   inflating: train/YNWHQVSS.ogg
#   inflating: train/YNXJQBSJ.ogg
#   inflating: train/YNXWMSAW.ogg
#   inflating: train/YNYAIYVA.ogg
#   inflating: train/YNYKHWDS.ogg
#   inflating: train/YNYLEKRB.ogg
#   inflating: train/YNYNSVAC.ogg
#   inflating: train/YNYZNSMJ.ogg
#   inflating: train/YNZCKQYX.ogg
#   inflating: train/YNZWBVPM.ogg
#   inflating: train/YOACQXXD.ogg
#   inflating: train/YOAGDMPJ.ogg
#   inflating: train/YOAGMHDN.ogg
#   inflating: train/YOAIWTEF.ogg
#   inflating: train/YOASOVHV.ogg
#   inflating: train/YOBBYBWG.ogg
#   inflating: train/YOBDCEMR.ogg
#   inflating: train/YOBQPKWX.ogg
#   inflating: train/YOBSUBLP.ogg
#   inflating: train/YOCDSTJF.ogg
#   inflating: train/YOCKQXFE.ogg
#   inflating: train/YOCUBUYX.ogg
#   inflating: train/YOCVSXYQ.ogg
#   inflating: train/YOCZQTZZ.ogg
#   inflating: train/YODYIVQE.ogg
#   inflating: train/YOEWZSZY.ogg
#   inflating: train/YOFDQIWC.ogg
#   inflating: train/YOFSPHIS.ogg
#   inflating: train/YOFVHSNM.ogg
#   inflating: train/YOFZYVDG.ogg
#   inflating: train/YOGDZDRS.ogg
#   inflating: train/YOGFLEQM.ogg
#   inflating: train/YOGJRNWA.ogg
#   inflating: train/YOGRFMOL.ogg
#   inflating: train/YOGVTBNO.ogg
#   inflating: train/YOHCPLHK.ogg
#   inflating: train/YOHRXSAR.ogg
#   inflating: train/YOIDAXKD.ogg
#   inflating: train/YOIMCLQV.ogg
#   inflating: train/YOIVDHKQ.ogg
#   inflating: train/YOKBGRFL.ogg
#   inflating: train/YOKFSDFC.ogg
#   inflating: train/YOKFSLOC.ogg
#   inflating: train/YOLAQSIU.ogg
#   inflating: train/YOLFXIDQ.ogg
#   inflating: train/YOLRPZLK.ogg
#   inflating: train/YOLYNQTR.ogg
#   inflating: train/YOMLZCKG.ogg
#   inflating: train/YONJALUB.ogg
#   inflating: train/YONJRNKH.ogg
#   inflating: train/YOOILDLG.ogg
#   inflating: train/YOONHNRC.ogg
#   inflating: train/YOOUJYWM.ogg
#   inflating: train/YOOYOQNL.ogg
#   inflating: train/YOQEWRDL.ogg
#   inflating: train/YOQRLHNI.ogg
#   inflating: train/YORDPOTZ.ogg
#   inflating: train/YORMTFAM.ogg
#   inflating: train/YOSBDTFU.ogg
#   inflating: train/YOSCKPPT.ogg
#   inflating: train/YOSEOVMD.ogg
#   inflating: train/YOSQAUCO.ogg
#   inflating: train/YOTHJUNE.ogg
#   inflating: train/YOTMXKMZ.ogg
#   inflating: train/YOTPEBNW.ogg
#   inflating: train/YOTSJUDR.ogg
#   inflating: train/YOTWCHAG.ogg
#   inflating: train/YOULDZFN.ogg
#   inflating: train/YOUWUNGX.ogg
#   inflating: train/YOVEGGIK.ogg
#   inflating: train/YOVNGPQE.ogg
#   inflating: train/YOVRWRWC.ogg
#   inflating: train/YOVTWVXT.ogg
#   inflating: train/YOVYZICB.ogg
#   inflating: train/YOXMSIIP.ogg
#   inflating: train/YOXQVCEQ.ogg
#   inflating: train/YOXSIFIL.ogg
#   inflating: train/YOXVIWDE.ogg
#   inflating: train/YOYENLZE.ogg
#   inflating: train/YOYGCBCL.ogg
#   inflating: train/YOYJFRMR.ogg
#   inflating: train/YOYMQEYA.ogg
#   inflating: train/YOYOXNSM.ogg
#   inflating: train/YOYQTATW.ogg
#   inflating: train/YOYUNAVP.ogg
#   inflating: train/YOYZAWJW.ogg
#   inflating: train/YOZPAHDL.ogg
#   inflating: train/YOZZZKJI.ogg
#   inflating: train/YPADYGLK.ogg
#   inflating: train/YPAESWUM.ogg
#   inflating: train/YPAGXRPX.ogg
#   inflating: train/YPALFEQY.ogg
#   inflating: train/YPAQJWYE.ogg
#   inflating: train/YPAWWBYT.ogg
#   inflating: train/YPAWYYBN.ogg
#   inflating: train/YPAYKROU.ogg
#   inflating: train/YPBBXBKZ.ogg
#   inflating: train/YPBIFFWS.ogg
#   inflating: train/YPBTMOVK.ogg
#   inflating: train/YPCXUUQJ.ogg
#   inflating: train/YPCYSXOM.ogg
#   inflating: train/YPEMXPLV.ogg
#   inflating: train/YPEYTSDI.ogg
#   inflating: train/YPFURWKK.ogg
#   inflating: train/YPGGYITT.ogg
#   inflating: train/YPGLBJHS.ogg
#   inflating: train/YPGXJVHA.ogg
#   inflating: train/YPHABHIA.ogg
#   inflating: train/YPHBMLJA.ogg
#   inflating: train/YPHIZDEA.ogg
#   inflating: train/YPICYUQT.ogg
#   inflating: train/YPIGLZIL.ogg
#   inflating: train/YPJVFMVV.ogg
#   inflating: train/YPJXELAF.ogg
#   inflating: train/YPKMZQJC.ogg
#   inflating: train/YPLPSYSM.ogg
#   inflating: train/YPLRHLNS.ogg
#   inflating: train/YPLRTZPW.ogg
#   inflating: train/YPLYCYUW.ogg
#   inflating: train/YPMDUJRH.ogg
#   inflating: train/YPMDWRCN.ogg
#   inflating: train/YPMQMXKL.ogg
#   inflating: train/YPNCGREP.ogg
#   inflating: train/YPNKLFHJ.ogg
#   inflating: train/YPNKQPCK.ogg
#   inflating: train/YPNLQBOI.ogg
#   inflating: train/YPNYTQRO.ogg
#   inflating: train/YPNZAOXO.ogg
#   inflating: train/YPNZPVBX.ogg
#   inflating: train/YPODPXNE.ogg
#   inflating: train/YPONANDT.ogg
#   inflating: train/YPOTJCRN.ogg
#   inflating: train/YPPBDAFN.ogg
#   inflating: train/YPPWLMZX.ogg
#   inflating: train/YPQBFONN.ogg
#   inflating: train/YPQFTKTX.ogg
#   inflating: train/YPQGRRCD.ogg
#   inflating: train/YPQKWUWI.ogg
#   inflating: train/YPQMKRUC.ogg
#   inflating: train/YPQPOLLC.ogg
#   inflating: train/YPQTCMWL.ogg
#   inflating: train/YPRNBBXM.ogg
#   inflating: train/YPRRBXTC.ogg
#   inflating: train/YPRRFJDT.ogg
#   inflating: train/YPSPBFUO.ogg
#   inflating: train/YPSXKEXM.ogg
#   inflating: train/YPTGYWGI.ogg
#   inflating: train/YPTMNCJQ.ogg
#   inflating: train/YPTRZUWX.ogg
#   inflating: train/YPTTAVBJ.ogg
#   inflating: train/YPUBWBRD.ogg
#   inflating: train/YPVCUDBD.ogg
#   inflating: train/YPVXAFOR.ogg
#   inflating: train/YPWDAHNU.ogg
#   inflating: train/YPXMNDLP.ogg
#   inflating: train/YPYNLXAC.ogg
#   inflating: train/YPYPITFL.ogg
#   inflating: train/YPYRMOPE.ogg
#   inflating: train/YPZARFWT.ogg
#   inflating: train/YPZGCMVF.ogg
#   inflating: train/YPZGRZEA.ogg
#   inflating: train/YQAHDPST.ogg
#   inflating: train/YQAHNQNU.ogg
#   inflating: train/YQAKBHWG.ogg
#   inflating: train/YQAQAAPG.ogg
#   inflating: train/YQAUUKVX.ogg
#   inflating: train/YQBNZXBM.ogg
#   inflating: train/YQBYTZUL.ogg
#   inflating: train/YQCEPLKP.ogg
#   inflating: train/YQCESXHW.ogg
#   inflating: train/YQCIEEKF.ogg
#   inflating: train/YQCOFKVZ.ogg
#   inflating: train/YQDDXQBG.ogg
#   inflating: train/YQEBKOBZ.ogg
#   inflating: train/YQEEZQKH.ogg
#   inflating: train/YQEFOQNT.ogg
#   inflating: train/YQFCJVSG.ogg
#   inflating: train/YQFEPSWU.ogg
#   inflating: train/YQFEQPTI.ogg
#   inflating: train/YQFIRJMB.ogg
#   inflating: train/YQFLWVBD.ogg
#   inflating: train/YQFWWEJC.ogg
#   inflating: train/YQGINVVK.ogg
#   inflating: train/YQGNQKNX.ogg
#   inflating: train/YQGSPIRF.ogg
#   inflating: train/YQHBGAET.ogg
#   inflating: train/YQHPNCEU.ogg
#   inflating: train/YQHRIUHC.ogg
#   inflating: train/YQHWASUX.ogg
#   inflating: train/YQIDDSSA.ogg
#   inflating: train/YQIDLUOR.ogg
#   inflating: train/YQIQTJFZ.ogg
#   inflating: train/YQIVVJVE.ogg
#   inflating: train/YQJBUMNU.ogg
#   inflating: train/YQJCCDME.ogg
#   inflating: train/YQJEHVIB.ogg
#   inflating: train/YQJGCBXS.ogg
#   inflating: train/YQKKHBXE.ogg
#   inflating: train/YQKUDAHA.ogg
#   inflating: train/YQLJVTKB.ogg
#   inflating: train/YQLWQXZT.ogg
#   inflating: train/YQMNYVHR.ogg
#   inflating: train/YQMZBGFH.ogg
#   inflating: train/YQNCMGVO.ogg
#   inflating: train/YQNCMXBW.ogg
#   inflating: train/YQNDURXQ.ogg
#   inflating: train/YQNJQFKJ.ogg
#   inflating: train/YQNSLWNZ.ogg
#   inflating: train/YQNZBPEJ.ogg
#   inflating: train/YQOGNJDP.ogg
#   inflating: train/YQOGPHXL.ogg
#   inflating: train/YQOHHSPG.ogg
#   inflating: train/YQOOHSOT.ogg
#   inflating: train/YQOSZEQR.ogg
#   inflating: train/YQOTZENT.ogg
#   inflating: train/YQPLTGXF.ogg
#   inflating: train/YQQARPXM.ogg
#   inflating: train/YQQCIQAW.ogg
#   inflating: train/YQQGIELK.ogg
#   inflating: train/YQRJSXAH.ogg
#   inflating: train/YQRJTQAX.ogg
#   inflating: train/YQRZJBNU.ogg
#   inflating: train/YQRZKPZF.ogg
#   inflating: train/YQSIRDQL.ogg
#   inflating: train/YQSMIEEZ.ogg
#   inflating: train/YQSXMILV.ogg
#   inflating: train/YQSZQGVR.ogg
#   inflating: train/YQTBZDJP.ogg
#   inflating: train/YQTCLEVZ.ogg
#   inflating: train/YQTCVBDM.ogg
#   inflating: train/YQTDIZSZ.ogg
#   inflating: train/YQTRZHJN.ogg
#   inflating: train/YQUCXWUX.ogg
#   inflating: train/YQUEKMFN.ogg
#   inflating: train/YQUIIWMQ.ogg
#   inflating: train/YQVCMBFY.ogg
#   inflating: train/YQVNLDJX.ogg
#   inflating: train/YQVTSCTF.ogg
#   inflating: train/YQVWIDPM.ogg
#   inflating: train/YQWCVYHN.ogg
#   inflating: train/YQXIZTIL.ogg
#   inflating: train/YQXKXHNG.ogg
#   inflating: train/YQXLHUVE.ogg
#   inflating: train/YQXRSIWS.ogg
#   inflating: train/YQXWRLJF.ogg
#   inflating: train/YQYFBBYU.ogg
#   inflating: train/YQYGMCUU.ogg
#   inflating: train/YQYICNAZ.ogg
#   inflating: train/YQYWLTGB.ogg
#   inflating: train/YQZAOPZC.ogg
#   inflating: train/YQZCUIBC.ogg
#   inflating: train/YQZHMXZR.ogg
#   inflating: train/YQZJENEV.ogg
#   inflating: train/YQZMPHYM.ogg
#   inflating: train/YQZRGVTR.ogg
#   inflating: train/YQZTCGVK.ogg
#   inflating: train/YRAAZKNV.ogg
#   inflating: train/YRAMMLMH.ogg
#   inflating: train/YRAUEGTK.ogg
#   inflating: train/YRBIDSMX.ogg
#   inflating: train/YRBPPLZG.ogg
#   inflating: train/YRCRDZQJ.ogg
#   inflating: train/YRCXIAHZ.ogg
#   inflating: train/YRDPJUJS.ogg
#   inflating: train/YREVHSZC.ogg
#   inflating: train/YRFBMETW.ogg
#   inflating: train/YRFQWZIW.ogg
#   inflating: train/YRFTPEDB.ogg
#   inflating: train/YRFTRAYR.ogg
#   inflating: train/YRGKSOZO.ogg
#   inflating: train/YRGSHQVP.ogg
#   inflating: train/YRGVNZIT.ogg
#   inflating: train/YRHTRLMK.ogg
#   inflating: train/YRIFISLS.ogg
#   inflating: train/YRIKHAEO.ogg
#   inflating: train/YRILEOJO.ogg
#   inflating: train/YRIRGZHC.ogg
#   inflating: train/YRIUPCDB.ogg
#   inflating: train/YRIVPKLP.ogg
#   inflating: train/YRJRAKYH.ogg
#   inflating: train/YRJUUAZF.ogg
#   inflating: train/YRKBKXNU.ogg
#   inflating: train/YRKCQFRO.ogg
#   inflating: train/YRKPCZNO.ogg
#   inflating: train/YRKQFEJS.ogg
#   inflating: train/YRKUXPNU.ogg
#   inflating: train/YRKVWWBP.ogg
#   inflating: train/YRLFAIMN.ogg
#   inflating: train/YRLLEUMS.ogg
#   inflating: train/YRLODEQT.ogg
#   inflating: train/YRLSVAVQ.ogg
#   inflating: train/YRLZXRAQ.ogg
#   inflating: train/YRMRIQTY.ogg
#   inflating: train/YRNCGASS.ogg
#   inflating: train/YRNEMSRD.ogg
#   inflating: train/YRNFYJTS.ogg
#   inflating: train/YRNGKNRG.ogg
#   inflating: train/YROFSBJN.ogg
#   inflating: train/YROWCWYU.ogg
#   inflating: train/YROZGWMG.ogg
#   inflating: train/YRPPZVNI.ogg
#   inflating: train/YRPUNHQG.ogg
#   inflating: train/YRQBUTNL.ogg
#   inflating: train/YRQHTMQU.ogg
#   inflating: train/YRQOZDQF.ogg
#   inflating: train/YRQPTLXM.ogg
#   inflating: train/YRQVWDPF.ogg
#   inflating: train/YRQYJYYI.ogg
#   inflating: train/YRRCPKSC.ogg
#   inflating: train/YRRJMXKE.ogg
#   inflating: train/YRRKUTUZ.ogg
#   inflating: train/YRRONWEX.ogg
#   inflating: train/YRRYVZIZ.ogg
#   inflating: train/YRSALSKL.ogg
#   inflating: train/YRSPSGPJ.ogg
#   inflating: train/YRTBCFCH.ogg
#   inflating: train/YRTCHIRT.ogg
#   inflating: train/YRTGARSC.ogg
#   inflating: train/YRTKQVLM.ogg
#   inflating: train/YRTVUSNB.ogg
#   inflating: train/YRTYLFWN.ogg
#   inflating: train/YRUFJCYC.ogg
#   inflating: train/YRUKFZOT.ogg
#   inflating: train/YRUZPEPJ.ogg
#   inflating: train/YRVDQTOA.ogg
#   inflating: train/YRVNCOLL.ogg
#   inflating: train/YRVVWVWD.ogg
#   inflating: train/YRWAKHXM.ogg
#   inflating: train/YRWDVKAP.ogg
#   inflating: train/YRWHGPXJ.ogg
#   inflating: train/YRWLMNFD.ogg
#   inflating: train/YRXNKSVL.ogg
#   inflating: train/YRZMNRYC.ogg
#   inflating: train/YSAGCRZF.ogg
#   inflating: train/YSASHDTO.ogg
#   inflating: train/YSBBQXJS.ogg
#   inflating: train/YSBMVFDD.ogg
#   inflating: train/YSBPTNRB.ogg
#   inflating: train/YSCGBUVE.ogg
#   inflating: train/YSCTTUFS.ogg
#   inflating: train/YSCUUDVM.ogg
#   inflating: train/YSDNFKYE.ogg
#   inflating: train/YSDZQWRU.ogg
#   inflating: train/YSEQAUNH.ogg
#   inflating: train/YSETGSLH.ogg
#   inflating: train/YSEWXUPI.ogg
#   inflating: train/YSGOAPCN.ogg
#   inflating: train/YSGWDCMU.ogg
#   inflating: train/YSHVAZFT.ogg
#   inflating: train/YSHXMRGA.ogg
#   inflating: train/YSHZWVOC.ogg
#   inflating: train/YSIDIJOK.ogg
#   inflating: train/YSILBEYB.ogg
#   inflating: train/YSIQHYTO.ogg
#   inflating: train/YSIQZKPQ.ogg
#   inflating: train/YSJEGJBH.ogg
#   inflating: train/YSJLCIDR.ogg
#   inflating: train/YSJVPYGP.ogg
#   inflating: train/YSKICBRD.ogg
#   inflating: train/YSKNTWLQ.ogg
#   inflating: train/YSKPSTMY.ogg
#   inflating: train/YSKRHDZE.ogg
#   inflating: train/YSKUXTGU.ogg
#   inflating: train/YSKXYASV.ogg
#   inflating: train/YSLHLEPS.ogg
#   inflating: train/YSLOIJGY.ogg
#   inflating: train/YSLRQVBU.ogg
#   inflating: train/YSLZJAQX.ogg
#   inflating: train/YSMJAJFM.ogg
#   inflating: train/YSMUHOHV.ogg
#   inflating: train/YSNGXIQM.ogg
#   inflating: train/YSOBPNEF.ogg
#   inflating: train/YSOIGGUR.ogg
#   inflating: train/YSPBFCUW.ogg
#   inflating: train/YSPHHYAF.ogg
#   inflating: train/YSPNMHOJ.ogg
#   inflating: train/YSQAOJTP.ogg
#   inflating: train/YSQJMPHK.ogg
#   inflating: train/YSQKXIAF.ogg
#   inflating: train/YSQKXWYX.ogg
#   inflating: train/YSQVNLXR.ogg
#   inflating: train/YSRNIYIW.ogg
#   inflating: train/YSRXGNLI.ogg
#   inflating: train/YSSENXVF.ogg
#   inflating: train/YSSQARSV.ogg
#   inflating: train/YSSYQLBZ.ogg
#   inflating: train/YSTCJFTQ.ogg
#   inflating: train/YSTMGTOD.ogg
#   inflating: train/YSTSWXIA.ogg
#   inflating: train/YSTVPBWU.ogg
#   inflating: train/YSTXKFDO.ogg
#   inflating: train/YSUDYBNY.ogg
#   inflating: train/YSUNJEQZ.ogg
#   inflating: train/YSUZTJTJ.ogg
#   inflating: train/YSVEVVIM.ogg
#   inflating: train/YSVGOKRB.ogg
#   inflating: train/YSVREAZZ.ogg
#   inflating: train/YSWCBGJK.ogg
#   inflating: train/YSWTFKYG.ogg
#   inflating: train/YSXACFCW.ogg
#   inflating: train/YSXAXTES.ogg
#   inflating: train/YSXGXJGP.ogg
#   inflating: train/YSXHJOUQ.ogg
#   inflating: train/YSXQIUGB.ogg
#   inflating: train/YSYGMPWF.ogg
#   inflating: train/YSYHESMO.ogg
#   inflating: train/YSYVKXDN.ogg
#   inflating: train/YSZAHGDT.ogg
#   inflating: train/YTAJNKYG.ogg
#   inflating: train/YTANZTKH.ogg
#   inflating: train/YTAPVLRB.ogg
#   inflating: train/YTCJHOSA.ogg
#   inflating: train/YTCPGMKU.ogg
#   inflating: train/YTCRACUN.ogg
#   inflating: train/YTDFRKOQ.ogg
#   inflating: train/YTDOPXVR.ogg
#   inflating: train/YTDXSDWZ.ogg
#   inflating: train/YTEAZFUF.ogg
#   inflating: train/YTEFZWCY.ogg
#   inflating: train/YTEJMPOD.ogg
#   inflating: train/YTEKOCIM.ogg
#   inflating: train/YTEMBXQY.ogg
#   inflating: train/YTEPONZF.ogg
#   inflating: train/YTERCXSO.ogg
#   inflating: train/YTETLJTK.ogg
#   inflating: train/YTFGSLRM.ogg
#   inflating: train/YTFTBOFZ.ogg
#   inflating: train/YTGERPIK.ogg
#   inflating: train/YTGJRNDD.ogg
#   inflating: train/YTGJXMDM.ogg
#   inflating: train/YTGVEJNH.ogg
#   inflating: train/YTGVGJPU.ogg
#   inflating: train/YTGXGPDF.ogg
#   inflating: train/YTHEDGIS.ogg
#   inflating: train/YTHUIUUZ.ogg
#   inflating: train/YTIELSSY.ogg
#   inflating: train/YTINQGHU.ogg
#   inflating: train/YTIQPSNR.ogg
#   inflating: train/YTIVTBCA.ogg
#   inflating: train/YTJGZVGL.ogg
#   inflating: train/YTJYAQMP.ogg
#   inflating: train/YTKAIXEB.ogg
#   inflating: train/YTKCLMNA.ogg
#   inflating: train/YTKDHQVI.ogg
#   inflating: train/YTKFZYOR.ogg
#   inflating: train/YTKIRNDH.ogg
#   inflating: train/YTKYFAMR.ogg
#   inflating: train/YTLKVTHX.ogg
#   inflating: train/YTLWJTHQ.ogg
#   inflating: train/YTLYNKQL.ogg
#   inflating: train/YTMDPUYS.ogg
#   inflating: train/YTMNMTSG.ogg
#   inflating: train/YTMVOTQI.ogg
#   inflating: train/YTMWPPJL.ogg
#   inflating: train/YTMXVDSD.ogg
#   inflating: train/YTNBESGG.ogg
#   inflating: train/YTNCUKXC.ogg
#   inflating: train/YTNNGHLM.ogg
#   inflating: train/YTNNLBSY.ogg
#   inflating: train/YTOVKRXG.ogg
#   inflating: train/YTPIHOIH.ogg
#   inflating: train/YTPIQIBP.ogg
#   inflating: train/YTPJRDDE.ogg
#   inflating: train/YTPMJRBQ.ogg
#   inflating: train/YTQEFSDB.ogg
#   inflating: train/YTQIYCHZ.ogg
#   inflating: train/YTQPCCWK.ogg
#   inflating: train/YTRIVXHT.ogg
#   inflating: train/YTRJXRSS.ogg
#   inflating: train/YTRPJJEP.ogg
#   inflating: train/YTSDDTBN.ogg
#   inflating: train/YTSLJKSV.ogg
#   inflating: train/YTSPABIT.ogg
#   inflating: train/YTSRQRWF.ogg
#   inflating: train/YTSTISRA.ogg
#   inflating: train/YTSYZOHP.ogg
#   inflating: train/YTTMNFIX.ogg
#   inflating: train/YTUDKOPD.ogg
#   inflating: train/YTUHDKAA.ogg
#   inflating: train/YTUHUAYV.ogg
#   inflating: train/YTUIEOUY.ogg
#   inflating: train/YTUPREQU.ogg
#   inflating: train/YTVAXRXM.ogg
#   inflating: train/YTVPREKV.ogg
#   inflating: train/YTVVUJCR.ogg
#   inflating: train/YTWPPXWF.ogg
#   inflating: train/YTWWLKQV.ogg
#   inflating: train/YTXMUYXE.ogg
#   inflating: train/YTXNOOQI.ogg
#   inflating: train/YTXUVGRW.ogg
#   inflating: train/YTXVAGST.ogg
#   inflating: train/YTXVYBTL.ogg
#   inflating: train/YTYJPECR.ogg
#   inflating: train/YTYSOQFC.ogg
#   inflating: train/YTYSSKVV.ogg
#   inflating: train/YUAHSNGJ.ogg
#   inflating: train/YUBAMWDY.ogg
#   inflating: train/YUCPTJJV.ogg
#   inflating: train/YUCXOWIC.ogg
#   inflating: train/YUCZGWGT.ogg
#   inflating: train/YUDCFSYI.ogg
#   inflating: train/YUDIFDZZ.ogg
#   inflating: train/YUDKIDKS.ogg
#   inflating: train/YUDMVBQW.ogg
#   inflating: train/YUEEPVVO.ogg
#   inflating: train/YUEHQZTL.ogg
#   inflating: train/YUEMCGMI.ogg
#   inflating: train/YUEQMMBV.ogg
#   inflating: train/YUERQDTP.ogg
#   inflating: train/YUEZPRHJ.ogg
#   inflating: train/YUFPLGYN.ogg
#   inflating: train/YUFQPJNT.ogg
#   inflating: train/YUFRCTBP.ogg
#   inflating: train/YUGCKDBI.ogg
#   inflating: train/YUGDCDYU.ogg
#   inflating: train/YUGFGGSN.ogg
#   inflating: train/YUGIMKKD.ogg
#   inflating: train/YUGJZVIT.ogg
#   inflating: train/YUGWNURL.ogg
#   inflating: train/YUHEVAWB.ogg
#   inflating: train/YUHFBVUA.ogg
#   inflating: train/YUHUZWAL.ogg
#   inflating: train/YUHWXCFR.ogg
#   inflating: train/YUILHNYE.ogg
#   inflating: train/YUIYXPPK.ogg
#   inflating: train/YUJOEMGB.ogg
#   inflating: train/YUJYMQKY.ogg
#   inflating: train/YUKTTMSG.ogg
#   inflating: train/YUKWRCFF.ogg
#   inflating: train/YUKXLXDN.ogg
#   inflating: train/YUKYYXXV.ogg
#   inflating: train/YULAGVEM.ogg
#   inflating: train/YULHRNCV.ogg
#   inflating: train/YULTDACC.ogg
#   inflating: train/YULVQTJH.ogg
#   inflating: train/YUMNWYBC.ogg
#   inflating: train/YUMVKMQQ.ogg
#   inflating: train/YUMWZPXI.ogg
#   inflating: train/YUMZNCCS.ogg
#   inflating: train/YUNCSAOC.ogg
#   inflating: train/YUNDBVDS.ogg
#   inflating: train/YUNFXDVO.ogg
#   inflating: train/YUNHDGJC.ogg
#   inflating: train/YUNOQFEP.ogg
#   inflating: train/YUNRPVPC.ogg
#   inflating: train/YUOETVKI.ogg
#   inflating: train/YUOFPYXS.ogg
#   inflating: train/YUOPSDFF.ogg
#   inflating: train/YUOSOHFO.ogg
#   inflating: train/YUOTJPNG.ogg
#   inflating: train/YUOXLVLY.ogg
#   inflating: train/YUPBLPAN.ogg
#   inflating: train/YUQHXQAU.ogg
#   inflating: train/YUQJNLKA.ogg
#   inflating: train/YUQNRKKK.ogg
#   inflating: train/YUQQVNVD.ogg
#   inflating: train/YUQWITBR.ogg
#   inflating: train/YURONSPQ.ogg
#   inflating: train/YURRLTCR.ogg
#   inflating: train/YUSBOAKB.ogg
#   inflating: train/YUSJMGCL.ogg
#   inflating: train/YUSLVXHU.ogg
#   inflating: train/YUTNIEAR.ogg
#   inflating: train/YUUEYCTG.ogg
#   inflating: train/YUUFSMZX.ogg
#   inflating: train/YUUHNCOU.ogg
#   inflating: train/YUUJBWUB.ogg
#   inflating: train/YUVKPQKE.ogg
#   inflating: train/YUVWFDME.ogg
#   inflating: train/YUWIBHZR.ogg
#   inflating: train/YUXHLRHT.ogg
#   inflating: train/YUXHYKJW.ogg
#   inflating: train/YUXHZHYF.ogg
#   inflating: train/YUXYADFD.ogg
#   inflating: train/YUXZDHZZ.ogg
#   inflating: train/YUYOTHUX.ogg
#   inflating: train/YUYRFRAI.ogg
#   inflating: train/YUYYHHOA.ogg
#   inflating: train/YUZBMYFG.ogg
#   inflating: train/YUZBXTLF.ogg
#   inflating: train/YUZOXOGZ.ogg
#   inflating: train/YUZSMGQS.ogg
#   inflating: train/YUZTKHDG.ogg
#   inflating: train/YVADOIMW.ogg
#   inflating: train/YVAERXYN.ogg
#   inflating: train/YVAPCZMY.ogg
#   inflating: train/YVBCWMLK.ogg
#   inflating: train/YVBDXVZG.ogg
#   inflating: train/YVBHNPJL.ogg
#   inflating: train/YVBQILZR.ogg
#   inflating: train/YVBQTNIN.ogg
#   inflating: train/YVBSYDXP.ogg
#   inflating: train/YVCDRZZU.ogg
#   inflating: train/YVCMLJPB.ogg
#   inflating: train/YVCMPVXI.ogg
#   inflating: train/YVCWEHSC.ogg
#   inflating: train/YVDJKZHB.ogg
#   inflating: train/YVDUOQDM.ogg
#   inflating: train/YVDXXQHQ.ogg
#   inflating: train/YVENJXQC.ogg
#   inflating: train/YVEXBYDO.ogg
#   inflating: train/YVFIPCZI.ogg
#   inflating: train/YVFOAZSF.ogg
#   inflating: train/YVFPJNAI.ogg
#   inflating: train/YVGIEWGU.ogg
#   inflating: train/YVHCWOAE.ogg
#   inflating: train/YVHWSYJH.ogg
#   inflating: train/YVIDBHWH.ogg
#   inflating: train/YVJBCNHA.ogg
#   inflating: train/YVJMBJYW.ogg
#   inflating: train/YVKDTLTE.ogg
#   inflating: train/YVKLNRHJ.ogg
#   inflating: train/YVKVQPTI.ogg
#   inflating: train/YVKVSLRZ.ogg
#   inflating: train/YVKZIGYF.ogg
#   inflating: train/YVLEKWLU.ogg
#   inflating: train/YVLKDOGX.ogg
#   inflating: train/YVMHPNGM.ogg
#   inflating: train/YVMKCMVM.ogg
#   inflating: train/YVMLUSJQ.ogg
#   inflating: train/YVMNZNWZ.ogg
#   inflating: train/YVMOFMGO.ogg
#   inflating: train/YVNFFVSW.ogg
#   inflating: train/YVNIGRVB.ogg
#   inflating: train/YVNPZIZT.ogg
#   inflating: train/YVOCXAON.ogg
#   inflating: train/YVOGZCYL.ogg
#   inflating: train/YVOOOSRI.ogg
#   inflating: train/YVPCWHSI.ogg
#   inflating: train/YVPLCDIW.ogg
#   inflating: train/YVPPOCXQ.ogg
#   inflating: train/YVQUTAPV.ogg
#   inflating: train/YVRCUCCY.ogg
#   inflating: train/YVRGWVTB.ogg
#   inflating: train/YVRIBNBT.ogg
#   inflating: train/YVSLZRXL.ogg
#   inflating: train/YVTAVZXD.ogg
#   inflating: train/YVTIKKZI.ogg
#   inflating: train/YVTXSYBM.ogg
#   inflating: train/YVUGUPEI.ogg
#   inflating: train/YVUKIYBO.ogg
#   inflating: train/YVUNZBQE.ogg
#   inflating: train/YVUTJRQX.ogg
#   inflating: train/YVUVGJYT.ogg
#   inflating: train/YVUYUVEP.ogg
#   inflating: train/YVVWTVFX.ogg
#   inflating: train/YVVZDUVB.ogg
#   inflating: train/YVWGGRMV.ogg
#   inflating: train/YVWIDZFV.ogg
#   inflating: train/YVWSXFSD.ogg
#   inflating: train/YVWWJIYF.ogg
#   inflating: train/YVXIVCJS.ogg
#   inflating: train/YVXRBIXM.ogg
#   inflating: train/YVXYDCJY.ogg
#   inflating: train/YVYBRNPD.ogg
#   inflating: train/YVYBTDZS.ogg
#   inflating: train/YVYLDRBE.ogg
#   inflating: train/YVYMZBIY.ogg
#   inflating: train/YVYSBIDW.ogg
#   inflating: train/YVZREMJP.ogg
#   inflating: train/YWAVAMIQ.ogg
#   inflating: train/YWAVNEMP.ogg
#   inflating: train/YWBFFTMU.ogg
#   inflating: train/YWBYJVQD.ogg
#   inflating: train/YWCCFTWJ.ogg
#   inflating: train/YWCPHWSF.ogg
#   inflating: train/YWCZOVQU.ogg
#   inflating: train/YWDMCFVZ.ogg
#   inflating: train/YWDSCJIQ.ogg
#   inflating: train/YWDYHUXK.ogg
#   inflating: train/YWENTUOP.ogg
#   inflating: train/YWEREOMF.ogg
#   inflating: train/YWFDNXME.ogg
#   inflating: train/YWFEWNZD.ogg
#   inflating: train/YWFLPZZW.ogg
#   inflating: train/YWFUICBW.ogg
#   inflating: train/YWFXWELW.ogg
#   inflating: train/YWFYKAVV.ogg
#   inflating: train/YWGROJOL.ogg
#   inflating: train/YWGWXVRR.ogg
# ...
#   inflating: unlabeled_data/SHJCJLVW.ogg
#   inflating: unlabeled_data/SHZGSQDY.ogg
#   inflating: unlabeled_data/SIQKLUVE.ogg
#   inflating: unlabeled_data/SIXDGWYP.ogg
#   inflating: unlabeled_data/SIXIPUNR.ogg
#   inflating: unlabeled_data/SJZSHKLC.ogg
#   inflating: unlabeled_data/SKAYBICH.ogg
#   inflating: unlabeled_data/SKEPRELQ.ogg
#   inflating: unlabeled_data/SKFYKAEK.ogg
#   inflating: unlabeled_data/SKIJXLJE.ogg
#   inflating: unlabeled_data/SLGWACHP.ogg
#   inflating: unlabeled_data/SLHATYJZ.ogg
#   inflating: unlabeled_data/SLLYVMBY.ogg
#   inflating: unlabeled_data/SLXEMPOQ.ogg
#   inflating: unlabeled_data/SNKJXOMR.ogg
#   inflating: unlabeled_data/SPNOXGEG.ogg
#   inflating: unlabeled_data/SPYITUUI.ogg
#   inflating: unlabeled_data/SRHCRDNT.ogg
#   inflating: unlabeled_data/SRTDXYFG.ogg
#   inflating: unlabeled_data/SRYSHWCG.ogg
#   inflating: unlabeled_data/SSLMXCGI.ogg
#   inflating: unlabeled_data/SSPOZGZS.ogg
#   inflating: unlabeled_data/SSUXSSQI.ogg
#   inflating: unlabeled_data/STYXKVNQ.ogg
#   inflating: unlabeled_data/SUDIDDKP.ogg
#   inflating: unlabeled_data/SUGEORKY.ogg
#   inflating: unlabeled_data/SUTGKJUF.ogg
#   inflating: unlabeled_data/SVVRWQJI.ogg
#   inflating: unlabeled_data/SWBHQUQT.ogg
#   inflating: unlabeled_data/SWGEYIFU.ogg
#   inflating: unlabeled_data/SWJGLUPP.ogg
#   inflating: unlabeled_data/SXWWTRHH.ogg
#   inflating: unlabeled_data/SYGCBOTH.ogg
#   inflating: unlabeled_data/SYNAXTBM.ogg
#   inflating: unlabeled_data/SZDFSWAI.ogg
#   inflating: unlabeled_data/SZVIOJQY.ogg
#   inflating: unlabeled_data/TAAFTZOP.ogg
#   inflating: unlabeled_data/TACNIEGX.ogg
#   inflating: unlabeled_data/TAHEQJIM.ogg
#   inflating: unlabeled_data/TANCCNRO.ogg
#   inflating: unlabeled_data/TAYAZIUA.ogg
#   inflating: unlabeled_data/TBIKNBNP.ogg
#   inflating: unlabeled_data/TBNBRLNS.ogg
#   inflating: unlabeled_data/TCTAOHMS.ogg
#   inflating: unlabeled_data/TGPTWEHE.ogg
#   inflating: unlabeled_data/TGQPKXOW.ogg
#   inflating: unlabeled_data/TGUKLBQL.ogg
#   inflating: unlabeled_data/THGQZWCK.ogg
#   inflating: unlabeled_data/THKNOLBK.ogg
#   inflating: unlabeled_data/THRMCGCI.ogg
#   inflating: unlabeled_data/TICLCHFV.ogg
#   inflating: unlabeled_data/TJSTYMTB.ogg
#   inflating: unlabeled_data/TJVFOMEN.ogg
#   inflating: unlabeled_data/TJYECIZJ.ogg
#   inflating: unlabeled_data/TKLDXMCK.ogg
#   inflating: unlabeled_data/TLKMGRBK.ogg
#   inflating: unlabeled_data/TLMRQEZD.ogg
#   inflating: unlabeled_data/TLPTDYUI.ogg
#   inflating: unlabeled_data/TLQBLIBL.ogg
#   inflating: unlabeled_data/TMHQSQCM.ogg
#   inflating: unlabeled_data/TMJKJCAS.ogg
#   inflating: unlabeled_data/TNBYMWDB.ogg
#   inflating: unlabeled_data/TOHRYJLD.ogg
#   inflating: unlabeled_data/TOKUZWHO.ogg
#   inflating: unlabeled_data/TOPMMKZN.ogg
#   inflating: unlabeled_data/TOSUMULM.ogg
#   inflating: unlabeled_data/TQHHACSB.ogg
#   inflating: unlabeled_data/TRLALQUA.ogg
#   inflating: unlabeled_data/TRQKXVJE.ogg
#   inflating: unlabeled_data/TSEVXBIN.ogg
#   inflating: unlabeled_data/TUCMOVHG.ogg
#   inflating: unlabeled_data/TUHLVKNN.ogg
#   inflating: unlabeled_data/TUKNQJTX.ogg
#   inflating: unlabeled_data/TUWZMHRT.ogg
#   inflating: unlabeled_data/TVNLMXDQ.ogg
#   inflating: unlabeled_data/TWHFHFNB.ogg
#   inflating: unlabeled_data/TWJNHHGP.ogg
#   inflating: unlabeled_data/TWKBKGIZ.ogg
#   inflating: unlabeled_data/TWLIWHRP.ogg
#   inflating: unlabeled_data/TWTHDIRG.ogg
#   inflating: unlabeled_data/TXCKTFFI.ogg
#   inflating: unlabeled_data/TXDUXBWX.ogg
#   inflating: unlabeled_data/TXEQKDJS.ogg
#   inflating: unlabeled_data/TXHCIBUE.ogg
#   inflating: unlabeled_data/TXOOUEQY.ogg
#   inflating: unlabeled_data/TXQSXDWD.ogg
#   inflating: unlabeled_data/TXVXOMWM.ogg
#   inflating: unlabeled_data/TZKCJKYB.ogg
#   inflating: unlabeled_data/TZMVTVAD.ogg
#   inflating: unlabeled_data/TZOZKATS.ogg
#   inflating: unlabeled_data/UBNWVQKA.ogg
#   inflating: unlabeled_data/UDLKVDEU.ogg
#   inflating: unlabeled_data/UDXSNHDH.ogg
#   inflating: unlabeled_data/UEEVNTBJ.ogg
#   inflating: unlabeled_data/UESQQGDA.ogg
#   inflating: unlabeled_data/UHFXOJCB.ogg
#   inflating: unlabeled_data/UHSOKIAU.ogg
#   inflating: unlabeled_data/UHTJULKG.ogg
#   inflating: unlabeled_data/UIDPMPAS.ogg
#   inflating: unlabeled_data/UIFEOQVN.ogg
#   inflating: unlabeled_data/UIWYLJPG.ogg
#   inflating: unlabeled_data/UJVJSMAW.ogg
#   inflating: unlabeled_data/UJXXTSTO.ogg
#   inflating: unlabeled_data/UJYAAVBL.ogg
#   inflating: unlabeled_data/ULGPQONR.ogg
#   inflating: unlabeled_data/UMCOBOUZ.ogg
#   inflating: unlabeled_data/UMDTIYYV.ogg
#   inflating: unlabeled_data/UMTZVHIP.ogg
#   inflating: unlabeled_data/UNBBGUAK.ogg
#   inflating: unlabeled_data/UNHXSLSM.ogg
#   inflating: unlabeled_data/UPSPLMTE.ogg
#   inflating: unlabeled_data/UQNTZSCU.ogg
#   inflating: unlabeled_data/URGIBZEU.ogg
#   inflating: unlabeled_data/URHLVURM.ogg
#   inflating: unlabeled_data/USSQJNOG.ogg
#   inflating: unlabeled_data/UTJBBENE.ogg
#   inflating: unlabeled_data/UUUINDDT.ogg
#   inflating: unlabeled_data/UWRBCJAW.ogg
#   inflating: unlabeled_data/UXSTRYDD.ogg
#   inflating: unlabeled_data/VANAGWJL.ogg
#   inflating: unlabeled_data/VBRHJQJK.ogg
#   inflating: unlabeled_data/VCLJFIRA.ogg
#   inflating: unlabeled_data/VCLNIIXU.ogg
#   inflating: unlabeled_data/VCLVDJEO.ogg
#   inflating: unlabeled_data/VCVTULEN.ogg
#   inflating: unlabeled_data/VDBDYXBQ.ogg
#   inflating: unlabeled_data/VDPGCSCS.ogg
#   inflating: unlabeled_data/VDSXPLHZ.ogg
#   inflating: unlabeled_data/VEAFXYZI.ogg
#   inflating: unlabeled_data/VEFANHGF.ogg
#   inflating: unlabeled_data/VEWPFEBB.ogg
#   inflating: unlabeled_data/VFFQTEOS.ogg
#   inflating: unlabeled_data/VHEWGWNX.ogg
#   inflating: unlabeled_data/VHRYITLQ.ogg
#   inflating: unlabeled_data/VIFMREDQ.ogg
#   inflating: unlabeled_data/VILOIRIX.ogg
#   inflating: unlabeled_data/VIOJFTYX.ogg
#   inflating: unlabeled_data/VJVDXWPE.ogg
#   inflating: unlabeled_data/VLBKIGOC.ogg
#   inflating: unlabeled_data/VMETCYHS.ogg
#   inflating: unlabeled_data/VMOXNQIS.ogg
#   inflating: unlabeled_data/VMQVXIDH.ogg
#   inflating: unlabeled_data/VNGYWRLE.ogg
#   inflating: unlabeled_data/VNJDMMGL.ogg
#   inflating: unlabeled_data/VNNLVAOT.ogg
#   inflating: unlabeled_data/VPAEVJYS.ogg
#   inflating: unlabeled_data/VPCSJUBT.ogg
#   inflating: unlabeled_data/VPHRUYWQ.ogg
#   inflating: unlabeled_data/VPMSIWWL.ogg
#   inflating: unlabeled_data/VRAPFXUQ.ogg
#   inflating: unlabeled_data/VRHZCIYF.ogg
#   inflating: unlabeled_data/VRNEZLHG.ogg
#   inflating: unlabeled_data/VSJVGQOL.ogg
#   inflating: unlabeled_data/VSOGFUYY.ogg
#   inflating: unlabeled_data/VSWFIHLM.ogg
#   inflating: unlabeled_data/VSWPPDEA.ogg
#   inflating: unlabeled_data/VTBCBFBD.ogg
#   inflating: unlabeled_data/VTDVNNJD.ogg
#   inflating: unlabeled_data/VTFEZZVA.ogg
#   inflating: unlabeled_data/VUUOXGAW.ogg
#   inflating: unlabeled_data/VUVLVQYG.ogg
#   inflating: unlabeled_data/VWGTAFKG.ogg
#   inflating: unlabeled_data/VWHGLRTQ.ogg
#   inflating: unlabeled_data/VXKGBQRF.ogg
#   inflating: unlabeled_data/VYLGQGDS.ogg
#   inflating: unlabeled_data/VZRGFUAX.ogg
#   inflating: unlabeled_data/VZTJDZBL.ogg
#   inflating: unlabeled_data/WADMEBYX.ogg
#   inflating: unlabeled_data/WBJFTXKJ.ogg
#   inflating: unlabeled_data/WBOEFNHI.ogg
#   inflating: unlabeled_data/WBUDGKCJ.ogg
#   inflating: unlabeled_data/WCKQGVPZ.ogg
#   inflating: unlabeled_data/WCRTAKDO.ogg
#   inflating: unlabeled_data/WCSSIMQV.ogg
#   inflating: unlabeled_data/WCUHQFGU.ogg
#   inflating: unlabeled_data/WCWPPDLO.ogg
#   inflating: unlabeled_data/WDHNVAMT.ogg
#   inflating: unlabeled_data/WEJHXSYX.ogg
#   inflating: unlabeled_data/WEQPADIG.ogg
#   inflating: unlabeled_data/WEZYDJBB.ogg
#   inflating: unlabeled_data/WFEEYCML.ogg
#   inflating: unlabeled_data/WFJBVKSR.ogg
#   inflating: unlabeled_data/WFTMRHBK.ogg
#   inflating: unlabeled_data/WFVDEZQO.ogg
#   inflating: unlabeled_data/WFWTDLSK.ogg
#   inflating: unlabeled_data/WGTUSGFX.ogg
#   inflating: unlabeled_data/WGUELEWD.ogg
#   inflating: unlabeled_data/WIISOCGE.ogg
#   inflating: unlabeled_data/WIPHDIVK.ogg
#   inflating: unlabeled_data/WJECKUDC.ogg
#   inflating: unlabeled_data/WJSXHRWU.ogg
#   inflating: unlabeled_data/WNDWTGFT.ogg
#   inflating: unlabeled_data/WNDYIMOJ.ogg
#   inflating: unlabeled_data/WOJPSVFA.ogg
#   inflating: unlabeled_data/WPGUZRTH.ogg
#   inflating: unlabeled_data/WPJVOYMK.ogg
#   inflating: unlabeled_data/WQWKQQEV.ogg
#   inflating: unlabeled_data/WRUUCSMJ.ogg
#   inflating: unlabeled_data/WSJPQJRY.ogg
#   inflating: unlabeled_data/WSPHFBPV.ogg
#   inflating: unlabeled_data/WSXDXKQL.ogg
#   inflating: unlabeled_data/WTQFKHIQ.ogg
#   inflating: unlabeled_data/WTQTCYGH.ogg
#   inflating: unlabeled_data/WTTGCZHL.ogg
#   inflating: unlabeled_data/WWDTCXJU.ogg
#   inflating: unlabeled_data/WWFFPFDJ.ogg
#   inflating: unlabeled_data/WWOXIYOI.ogg
#   inflating: unlabeled_data/WXKMXAUN.ogg
#   inflating: unlabeled_data/WXTZHVXY.ogg
#   inflating: unlabeled_data/WXYOQAIG.ogg
#   inflating: unlabeled_data/WYVDZWKK.ogg
#   inflating: unlabeled_data/WYWIFBAB.ogg
#   inflating: unlabeled_data/WZATYOGV.ogg
#   inflating: unlabeled_data/WZBJLRXO.ogg
#   inflating: unlabeled_data/XAEAUTRG.ogg
#   inflating: unlabeled_data/XAKJZTWY.ogg
#   inflating: unlabeled_data/XANBGHAP.ogg
#   inflating: unlabeled_data/XBKOUIAQ.ogg
#   inflating: unlabeled_data/XBUSHANN.ogg
#   inflating: unlabeled_data/XDGEGNUL.ogg
#   inflating: unlabeled_data/XDKGGNPX.ogg
#   inflating: unlabeled_data/XDYYMBRR.ogg
#   inflating: unlabeled_data/XEDSNXGQ.ogg
#   inflating: unlabeled_data/XEEOFSHS.ogg
#   inflating: unlabeled_data/XEGSQIRK.ogg
#   inflating: unlabeled_data/XEIVRENJ.ogg
#   inflating: unlabeled_data/XEJZTGZZ.ogg
#   inflating: unlabeled_data/XELHJJSK.ogg
#   inflating: unlabeled_data/XEMXAWEH.ogg
#   inflating: unlabeled_data/XFCOWURM.ogg
#   inflating: unlabeled_data/XFRJIUBF.ogg
#   inflating: unlabeled_data/XFWHASFW.ogg
#   inflating: unlabeled_data/XGDGAIIA.ogg
#   inflating: unlabeled_data/XGHOFSDR.ogg
#   inflating: unlabeled_data/XHGGRLEQ.ogg
#   inflating: unlabeled_data/XHOIZFTW.ogg
#   inflating: unlabeled_data/XIBFCQOV.ogg
#   inflating: unlabeled_data/XIUQBCSM.ogg
#   inflating: unlabeled_data/XJQCCIWQ.ogg
#   inflating: unlabeled_data/XJQHMDUA.ogg
#   inflating: unlabeled_data/XJQJLGLJ.ogg
#   inflating: unlabeled_data/XKZIOIIT.ogg
#   inflating: unlabeled_data/XLAWGDSM.ogg
#   inflating: unlabeled_data/XLEJBRWE.ogg
#   inflating: unlabeled_data/XLXWYAPT.ogg
#   inflating: unlabeled_data/XNTMGSZN.ogg
#   inflating: unlabeled_data/XNVHQWZD.ogg
#   inflating: unlabeled_data/XOGKVQEF.ogg
#   inflating: unlabeled_data/XPCIUBPA.ogg
#   inflating: unlabeled_data/XQMUMCUD.ogg
#   inflating: unlabeled_data/XQTYVNEB.ogg
#   inflating: unlabeled_data/XRBILKXF.ogg
#   inflating: unlabeled_data/XRHESRXU.ogg
#   inflating: unlabeled_data/XSRJRFIT.ogg
#   inflating: unlabeled_data/XSSKPJDE.ogg
#   inflating: unlabeled_data/XTPWFLBB.ogg
#   inflating: unlabeled_data/XTQXTHAH.ogg
#   inflating: unlabeled_data/XUJXSYIO.ogg
#   inflating: unlabeled_data/XUSGPVCP.ogg
#   inflating: unlabeled_data/XVRQIMSK.ogg
#   inflating: unlabeled_data/XWDFCFTN.ogg
#   inflating: unlabeled_data/XWDVISEC.ogg
#   inflating: unlabeled_data/XWKNNHTG.ogg
#   inflating: unlabeled_data/XWPSZUGM.ogg
#   inflating: unlabeled_data/XXQNAMTJ.ogg
#   inflating: unlabeled_data/XYDSAUNU.ogg
#   inflating: unlabeled_data/XZEACRDW.ogg
#   inflating: unlabeled_data/XZOCXOTD.ogg
#   inflating: unlabeled_data/XZRNQAEB.ogg
#   inflating: unlabeled_data/XZRPLXEO.ogg
#   inflating: unlabeled_data/XZYRQUYF.ogg
#   inflating: unlabeled_data/YAFBSDZT.ogg
#   inflating: unlabeled_data/YAIFZMQT.ogg
#   inflating: unlabeled_data/YAIWFSZI.ogg
#   inflating: unlabeled_data/YAJMPHEY.ogg
#   inflating: unlabeled_data/YAUSXGLQ.ogg
#   inflating: unlabeled_data/YAXGXNBW.ogg
#   inflating: unlabeled_data/YAZKRUZX.ogg
#   inflating: unlabeled_data/YBENYCGL.ogg
#   inflating: unlabeled_data/YBQPDAHI.ogg
#   inflating: unlabeled_data/YCBGJALR.ogg
#   inflating: unlabeled_data/YCGEDLUI.ogg
#   inflating: unlabeled_data/YDDCRMYL.ogg
#   inflating: unlabeled_data/YDSDZDSZ.ogg
#   inflating: unlabeled_data/YEDWIUCT.ogg
#   inflating: unlabeled_data/YEIJTZNV.ogg
#   inflating: unlabeled_data/YEVGAUSC.ogg
#   inflating: unlabeled_data/YFISKBJU.ogg
#   inflating: unlabeled_data/YFSKFVOA.ogg
#   inflating: unlabeled_data/YFTXJIMF.ogg
#   inflating: unlabeled_data/YGSYXELJ.ogg
#   inflating: unlabeled_data/YIFUNNLP.ogg
#   inflating: unlabeled_data/YJFWMFTH.ogg
#   inflating: unlabeled_data/YJXRGURP.ogg
#   inflating: unlabeled_data/YLJMFWMT.ogg
#   inflating: unlabeled_data/YLKAFKFK.ogg
#   inflating: unlabeled_data/YLUTTQFX.ogg
#   inflating: unlabeled_data/YLVROMCE.ogg
#   inflating: unlabeled_data/YMCDNIPI.ogg
#   inflating: unlabeled_data/YMCTIRLM.ogg
#   inflating: unlabeled_data/YMLNOEYG.ogg
#   inflating: unlabeled_data/YMLXTVAL.ogg
#   inflating: unlabeled_data/YMORIMWY.ogg
#   inflating: unlabeled_data/YNXCJHQS.ogg
#   inflating: unlabeled_data/YNZGWPZH.ogg
#   inflating: unlabeled_data/YNZVEDIE.ogg
#   inflating: unlabeled_data/YOWCEFRW.ogg
#   inflating: unlabeled_data/YOWPYBMM.ogg
#   inflating: unlabeled_data/YPRZCRAE.ogg
#   inflating: unlabeled_data/YQODEXPZ.ogg
#   inflating: unlabeled_data/YRBBCABE.ogg
#   inflating: unlabeled_data/YRHTTFYM.ogg
#   inflating: unlabeled_data/YRPRXHRW.ogg
#   inflating: unlabeled_data/YSEHCQSZ.ogg
#   inflating: unlabeled_data/YTCNYCWZ.ogg
#   inflating: unlabeled_data/YTDSJXFL.ogg
#   inflating: unlabeled_data/YUCVVCOU.ogg
#   inflating: unlabeled_data/YUXLETVR.ogg
#   inflating: unlabeled_data/YVPIVMCT.ogg
#   inflating: unlabeled_data/YWPQBQZR.ogg
#   inflating: unlabeled_data/YXLVSFLN.ogg
#   inflating: unlabeled_data/YZCJEIQK.ogg
#   inflating: unlabeled_data/YZUASZGP.ogg
#   inflating: unlabeled_data/YZUYXHDS.ogg
#   inflating: unlabeled_data/ZACCJWMV.ogg
#   inflating: unlabeled_data/ZADCKNAA.ogg
#   inflating: unlabeled_data/ZAHHAYYZ.ogg
#   inflating: unlabeled_data/ZAMUMNOR.ogg
#   inflating: unlabeled_data/ZAQCXLRY.ogg
#   inflating: unlabeled_data/ZAWVMAED.ogg
#   inflating: unlabeled_data/ZBPNUCRL.ogg
#   inflating: unlabeled_data/ZBTHEXIA.ogg
#   inflating: unlabeled_data/ZBUVSMRP.ogg
#   inflating: unlabeled_data/ZBZNGKVY.ogg
#   inflating: unlabeled_data/ZCSKRJDI.ogg
#   inflating: unlabeled_data/ZDLIURBM.ogg
#   inflating: unlabeled_data/ZDNYPFVB.ogg
#   inflating: unlabeled_data/ZDXCALDK.ogg
#   inflating: unlabeled_data/ZDZKWULT.ogg
#   inflating: unlabeled_data/ZEBIUAJR.ogg
#   inflating: unlabeled_data/ZFYZTAUG.ogg
#   inflating: unlabeled_data/ZGWAOECT.ogg
#   inflating: unlabeled_data/ZGZXEYNV.ogg
#   inflating: unlabeled_data/ZHGOVUQF.ogg
#   inflating: unlabeled_data/ZIKAHDQO.ogg
#   inflating: unlabeled_data/ZJEIQIGZ.ogg
#   inflating: unlabeled_data/ZJFKBZBM.ogg
#   inflating: unlabeled_data/ZJMIEUOH.ogg
#   inflating: unlabeled_data/ZJQHKPNS.ogg
#   inflating: unlabeled_data/ZLDEUKNQ.ogg
#   inflating: unlabeled_data/ZLDYCTCZ.ogg
#   inflating: unlabeled_data/ZLJXHPWB.ogg
#   inflating: unlabeled_data/ZLPPVQBR.ogg
#   inflating: unlabeled_data/ZLVPSUOF.ogg
#   inflating: unlabeled_data/ZLXXYUXC.ogg
#   inflating: unlabeled_data/ZMNXMFZG.ogg
#   inflating: unlabeled_data/ZNEUBVFG.ogg
#   inflating: unlabeled_data/ZNKETQPG.ogg
#   inflating: unlabeled_data/ZNKNSNKR.ogg
#   inflating: unlabeled_data/ZNVUXGCN.ogg
#   inflating: unlabeled_data/ZQPXXECI.ogg
#   inflating: unlabeled_data/ZQYZMISE.ogg
#   inflating: unlabeled_data/ZROOPFQL.ogg
#   inflating: unlabeled_data/ZSIDQYPY.ogg
#   inflating: unlabeled_data/ZUTQKXTH.ogg
#   inflating: unlabeled_data/ZVWEFDBU.ogg
#   inflating: unlabeled_data/ZXUNJOMW.ogg
#   inflating: unlabeled_data/ZXXYQAZT.ogg
#   inflating: unlabeled_data/ZXYKTQGY.ogg
#   inflating: unlabeled_data/ZYDCWUVX.ogg
#   inflating: unlabeled_data/ZYOASADS.ogg
#   inflating: unlabeled_data/ZYUAIDJD.ogg

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
class Config:
    SR = 32000
    N_MFCC = 13
    # Dataset
    ROOT_FOLDER = './'
    # Training
    N_CLASSES = 2
    BATCH_SIZE = 96
    N_EPOCHS = 5
    LR = 3e-4
    # Others
    SEED = 42

CONFIG = Config()

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CONFIG.SEED) # Seed 고정

# %%
df = pd.read_csv('./train.csv')
train, val, _, _ = train_test_split(df, df['label'], test_size=0.2, random_state=CONFIG.SEED)

# %%
def get_mfcc_feature(df, train_mode=True):
    features = []
    labels = []
    for _, row in tqdm(df.iterrows()):
        # librosa패키지를 사용하여 wav 파일 load
        y, sr = librosa.load(row['path'], sr=CONFIG.SR)

        # librosa패키지를 사용하여 mfcc 추출
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=CONFIG.N_MFCC)
        mfcc = np.mean(mfcc.T, axis=0)
        features.append(mfcc)

        if train_mode:
            label = row['label']
            label_vector = np.zeros(CONFIG.N_CLASSES, dtype=float)
            label_vector[0 if label == 'fake' else 1] = 1
            labels.append(label_vector)

    if train_mode:
        return features, labels
    return features

# %%
train_mfcc, train_labels = get_mfcc_feature(train, True)
val_mfcc, val_labels = get_mfcc_feature(val, True)
# Out:
# 44350it [17:12, 42.95it/s]
# 11088it [04:10, 44.19it/s]

# %%
class CustomDataset(Dataset):
    def __init__(self, mfcc, label):
        self.mfcc = mfcc
        self.label = label

    def __len__(self):
        return len(self.mfcc)

    def __getitem__(self, index):
        if self.label is not None:
            return self.mfcc[index], self.label[index]
        return self.mfcc[index]

# %%
train_dataset = CustomDataset(train_mfcc, train_labels)
val_dataset = CustomDataset(val_mfcc, val_labels)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=CONFIG.BATCH_SIZE,
    shuffle=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=CONFIG.BATCH_SIZE,
    shuffle=False
)

# %%
class MLP(nn.Module):
    def __init__(self, input_dim=CONFIG.N_MFCC, hidden_dim=128, output_dim=CONFIG.N_CLASSES):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        x = torch.sigmoid(x)
        return x

# %%
from sklearn.metrics import roc_auc_score

def train(model, optimizer, train_loader, val_loader, device):
    model.to(device)
    criterion = nn.BCELoss().to(device)

    best_val_score = 0
    best_model = None

    for epoch in range(1, CONFIG.N_EPOCHS+1):
        model.train()
        train_loss = []
        for features, labels in tqdm(iter(train_loader)):
            features = features.float().to(device)
            labels = labels.float().to(device)

            optimizer.zero_grad()

            output = model(features)
            loss = criterion(output, labels)

            loss.backward()
            optimizer.step()

            train_loss.append(loss.item())

        _val_loss, _val_score = validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val AUC : [{_val_score:.5f}]')

        if best_val_score < _val_score:
            best_val_score = _val_score
            best_model = model

    return best_model

def multiLabel_AUC(y_true, y_scores):
    auc_scores = []
    for i in range(y_true.shape[1]):
        auc = roc_auc_score(y_true[:, i], y_scores[:, i])
        auc_scores.append(auc)
    mean_auc_score = np.mean(auc_scores)
    return mean_auc_score

def validation(model, criterion, val_loader, device):
    model.eval()
    val_loss, all_labels, all_probs = [], [], []

    with torch.no_grad():
        for features, labels in tqdm(iter(val_loader)):
            features = features.float().to(device)
            labels = labels.float().to(device)

            probs = model(features)

            loss = criterion(probs, labels)

            val_loss.append(loss.item())

            all_labels.append(labels.cpu().numpy())
            all_probs.append(probs.cpu().numpy())

        _val_loss = np.mean(val_loss)

        all_labels = np.concatenate(all_labels, axis=0)
        all_probs = np.concatenate(all_probs, axis=0)

        # Calculate AUC score
        auc_score = multiLabel_AUC(all_labels, all_probs)

    return _val_loss, auc_score

# %%
model = MLP()
optimizer = torch.optim.Adam(params = model.parameters(), lr = CONFIG.LR)

infer_model = train(model, optimizer, train_loader, val_loader, device)
# Out:
# 100%|██████████| 462/462 [00:02<00:00, 202.85it/s]
# 100%|██████████| 116/116 [00:00<00:00, 618.70it/s]
# Epoch [1], Train Loss : [0.51093] Val Loss : [0.33744] Val AUC : [0.93560]
# 100%|██████████| 462/462 [00:01<00:00, 403.81it/s]
# 100%|██████████| 116/116 [00:00<00:00, 842.03it/s]
# Epoch [2], Train Loss : [0.31068] Val Loss : [0.28448] Val AUC : [0.95397]
# 100%|██████████| 462/462 [00:01<00:00, 413.11it/s]
# 100%|██████████| 116/116 [00:00<00:00, 874.99it/s]
# Epoch [3], Train Loss : [0.26747] Val Loss : [0.27039] Val AUC : [0.96240]
# 100%|██████████| 462/462 [00:01<00:00, 408.07it/s]
# 100%|██████████| 116/116 [00:00<00:00, 742.51it/s]
# Epoch [4], Train Loss : [0.23842] Val Loss : [0.22569] Val AUC : [0.96931]
# 100%|██████████| 462/462 [00:01<00:00, 407.02it/s]
# 100%|██████████| 116/116 [00:00<00:00, 836.07it/s]
# Epoch [5], Train Loss : [0.21854] Val Loss : [0.20937] Val AUC : [0.97350]

# %%
test = pd.read_csv('./test.csv')
test_mfcc = get_mfcc_feature(test, False)
test_dataset = CustomDataset(test_mfcc, None)
test_loader = DataLoader(
    test_dataset,
    batch_size=CONFIG.BATCH_SIZE,
    shuffle=False
)
# Out:
# 50000it [27:14, 30.59it/s]

# %%
def inference(model, test_loader, device):
    model.to(device)
    model.eval()
    predictions = []
    with torch.no_grad():
        for features in tqdm(iter(test_loader)):
            features = features.float().to(device)

            probs = model(features)

            probs  = probs.cpu().detach().numpy()
            predictions += probs.tolist()
    return predictions

# %%
preds = inference(infer_model, test_loader, device)
# Out:
# 100%|██████████| 521/521 [00:00<00:00, 798.50it/s]

# %%
submit = pd.read_csv('./sample_submission.csv')
submit.iloc[:, 1:] = preds
submit.head()
# Out:
#            id      fake      real
# 0  TEST_00000  0.275122  0.899597
# 1  TEST_00001  0.042682  0.979734
# 2  TEST_00002  0.065133  0.961473
# 3  TEST_00003  0.009338  0.985858
# 4  TEST_00004  0.175708  0.851360
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['fake'].plot(kind='hist', bins=20, title='fake')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['real'].plot(kind='hist', bins=20, title='real')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('id').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='fake', y='real', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['fake'].plot(kind='line', figsize=(8, 4), title='fake')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5['real'].plot(kind='line', figsize=(8, 4), title='real')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_6['id'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_6, x='fake', y='id', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_7['id'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_7, x='real', y='id', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
submit.to_csv('./baseline_submit.csv', index=False)
